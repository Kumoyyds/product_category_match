# %%
from sentence_transformers import SentenceTransformer
import os

# %%
model_path = os.getcwd() + '/model/all-mpnet-base-v2' # Or the full path to the folder
model = SentenceTransformer(model_path)

# %%
model.encode('hello_words')
# Out:
# array([ 1.91029757e-02,  2.04007700e-02, -4.20842494e-04,  2.40401505e-03,
#         7.13539403e-03,  7.55147822e-03, -3.41618806e-02,  3.39813232e-02,
#        -6.31472543e-02, -4.28346470e-02,  2.26967409e-02, -3.12030204e-02,
#         2.37187166e-02,  3.45475823e-02,  2.27436386e-02, -2.93279812e-02,
#         3.62161659e-02, -1.69076826e-02, -2.17083916e-02, -1.80096682e-02,
#        -1.81837566e-03,  4.09224778e-02, -1.47095630e-02,  3.18105705e-02,
#         3.26300692e-03, -6.78164302e-04,  4.47130110e-03, -4.43855375e-02,
#        -4.26173620e-02, -3.08949617e-03, -2.56741177e-02, -1.86748308e-04,
#         3.34059633e-02,  1.91442482e-02,  2.14285751e-06, -1.53509062e-02,
#        -3.88628356e-02,  1.00165745e-03,  1.28322421e-02, -3.85657996e-02,
#         1.72965042e-02, -3.11321132e-02,  2.55449302e-02,  4.29044440e-02,
#        -2.95624696e-02, -3.42995413e-02,  2.91472431e-02,  1.89442448e-02,
# ...
